# %%
import pandas as pd

# %%
df = pd.read_csv("ViewingActivity.csv")

# %%
df.dtypes
# Out:
# Profile Name               object
# Start Time                 object
# Duration                   object
# Attributes                 object
# Title                      object
# Supplemental Video Type    object
# Device Type                object
# Bookmark                   object
# Latest Bookmark            object
# Country                    object
# dtype: object

# %%
df.sample(10)
# Out:
#     Profile Name           Start Time  Duration  \
# 358           JB  2024-01-17 20:55:24  00:00:19
# 415           JB  2024-01-10 09:02:53  00:00:32
# 370           JB  2024-01-15 22:16:09  00:46:51
# 301           JB  2024-02-08 00:10:55  00:26:28
# 219           JB  2024-03-02 03:58:13  00:00:05
# 81            JB  2024-04-27 03:49:29  00:00:07
# 310           JB  2024-02-08 00:01:32  00:00:09
# 66            JB  2024-04-28 07:58:50  00:20:44
# 169           JB  2024-03-13 08:03:46  00:00:08
# 59            JB  2024-04-29 07:28:15  00:20:34
#
#                           Attributes  \
# 358                              NaN
# 415                              NaN
# 370                              NaN
# 301                              NaN
# 219  Autoplayed: user action: None;
# 81                               NaN
# 310  Autoplayed: user action: None;
# 66                               NaN
# 169                              NaN
# 59                               NaN
#
# ...

# %%
df.head(10)
# Out:
#   Profile Name           Start Time  Duration  \
# 0           JB  2024-05-06 19:29:13  00:29:31
# 1           JB  2024-05-06 09:47:24  00:24:03
# 2           JB  2024-05-06 09:47:11  00:00:04
# 3           JB  2024-05-06 08:51:44  00:21:12
# 4           JB  2024-05-06 08:31:35  00:19:55
# 5           JB  2024-05-06 08:11:05  00:20:28
# 6           JB  2024-05-06 07:51:29  00:19:34
# 7           JB  2024-05-06 07:20:27  00:19:37
# 8           JB  2024-05-06 06:48:53  00:20:09
# 9           JB  2024-05-06 06:28:23  00:19:37
#
#                         Attributes  \
# 0                              NaN
# 1                              NaN
# 2  Autoplayed: user action: None;
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
#
# ...

# %%
df["Start Time"] = pd.to_datetime(df["Start Time"], utc=True)

# %%
df["Duration"] = pd.to_timedelta(df["Duration"])

# %%
df
# Out:
#     Profile Name                Start Time        Duration  \
# 0             JB 2024-05-06 19:29:13+00:00 0 days 00:29:31
# 1             JB 2024-05-06 09:47:24+00:00 0 days 00:24:03
# 2             JB 2024-05-06 09:47:11+00:00 0 days 00:00:04
# 3             JB 2024-05-06 08:51:44+00:00 0 days 00:21:12
# 4             JB 2024-05-06 08:31:35+00:00 0 days 00:19:55
# ..           ...                       ...             ...
# 430           JB 2024-01-09 07:15:34+00:00 0 days 00:00:24
# 431           JB 2024-01-09 06:46:25+00:00 0 days 00:00:14
# 432           JB 2024-01-09 06:42:15+00:00 0 days 00:00:02
# 433           JB 2024-01-09 06:38:37+00:00 0 days 00:00:11
# 434           JB 2024-01-09 06:38:22+00:00 0 days 00:00:05
#
#                           Attributes  \
# 0                                NaN
# 1                                NaN
# 2    Autoplayed: user action: None;
# 3                                NaN
# 4                                NaN
# ...

# %%
df["Profile Name"].value_counts()
# Out:
# Profile Name
# JB    435
# Name: count, dtype: int64

# %%
df["Profile Name"].value_counts()
# Out:
# Profile Name
# JB    435
# Name: count, dtype: int64

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
df["Profile Name"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Profile Name'>

# %%
plt.show()

# %%
df["Duration"].sum()
# Out:
# Timedelta('3 days 11:54:47')

# %%
df.sort_values('Start Time')
# Out:
#     Profile Name                Start Time        Duration  \
# 434           JB 2024-01-09 06:38:22+00:00 0 days 00:00:05
# 433           JB 2024-01-09 06:38:37+00:00 0 days 00:00:11
# 432           JB 2024-01-09 06:42:15+00:00 0 days 00:00:02
# 431           JB 2024-01-09 06:46:25+00:00 0 days 00:00:14
# 430           JB 2024-01-09 07:15:34+00:00 0 days 00:00:24
# ..           ...                       ...             ...
# 4             JB 2024-05-06 08:31:35+00:00 0 days 00:19:55
# 3             JB 2024-05-06 08:51:44+00:00 0 days 00:21:12
# 2             JB 2024-05-06 09:47:11+00:00 0 days 00:00:04
# 1             JB 2024-05-06 09:47:24+00:00 0 days 00:24:03
# 0             JB 2024-05-06 19:29:13+00:00 0 days 00:29:31
#
#                           Attributes  \
# 434  Autoplayed: user action: None;
# 433  Autoplayed: user action: None;
# 432                              NaN
# 431  Autoplayed: user action: None;
# 430  Autoplayed: user action: None;
# ...

# %%
df.loc[df["Profile Name"] == "JB"]
# Out:
#     Profile Name                Start Time        Duration  \
# 0             JB 2024-05-06 19:29:13+00:00 0 days 00:29:31
# 1             JB 2024-05-06 09:47:24+00:00 0 days 00:24:03
# 2             JB 2024-05-06 09:47:11+00:00 0 days 00:00:04
# 3             JB 2024-05-06 08:51:44+00:00 0 days 00:21:12
# 4             JB 2024-05-06 08:31:35+00:00 0 days 00:19:55
# ..           ...                       ...             ...
# 430           JB 2024-01-09 07:15:34+00:00 0 days 00:00:24
# 431           JB 2024-01-09 06:46:25+00:00 0 days 00:00:14
# 432           JB 2024-01-09 06:42:15+00:00 0 days 00:00:02
# 433           JB 2024-01-09 06:38:37+00:00 0 days 00:00:11
# 434           JB 2024-01-09 06:38:22+00:00 0 days 00:00:05
#
#                           Attributes  \
# 0                                NaN
# 1                                NaN
# 2    Autoplayed: user action: None;
# 3                                NaN
# 4                                NaN
# ...

# %%
df['Duration'].sum()
# Out:
# Timedelta('3 days 11:54:47')

# %%
total_seconds_code_and_dogs = df.loc[df['Profile Name'] == 'JB', 'Duration'].astype('timedelta64[s]').sum()

# %%
print(total_seconds_code_and_dogs)
# Out:
# 3 days 11:54:47

# %%
pip install --upgrade pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
total_seconds_code_and_dogs = df.loc[df['Profile Name'] == 'JB', 'Duration'].astype('timedelta64[s]').sum()

# %%
print(total_seconds_code_and_dogs)
# Out:
# 3 days 11:54:47

# %%
individual_duration = df.loc[df['Profile Name'] == 'JB', 'Duration']
print(individual_duration)
# Out:
# 0     0 days 00:29:31
# 1     0 days 00:24:03
# 2     0 days 00:00:04
# 3     0 days 00:21:12
# 4     0 days 00:19:55
#             ...
# 430   0 days 00:00:24
# 431   0 days 00:00:14
# 432   0 days 00:00:02
# 433   0 days 00:00:11
# 434   0 days 00:00:05
# Name: Duration, Length: 435, dtype: timedelta64[ns]

# %%
print(type(individual_duration))
# Out:
# <class 'pandas.core.series.Series'>

# %%
total_seconds = individual_duration.astype('timedelta64[s]').sum()
print(total_seconds)  # This should print total seconds
# Out:
# 3 days 11:54:47

# %%
print(df['Duration'].isna().sum())
# Out:
# 0

# %%
df['Duration']
# Out:
# 0     0 days 00:29:31
# 1     0 days 00:24:03
# 2     0 days 00:00:04
# 3     0 days 00:21:12
# 4     0 days 00:19:55
#             ...
# 430   0 days 00:00:24
# 431   0 days 00:00:14
# 432   0 days 00:00:02
# 433   0 days 00:00:11
# 434   0 days 00:00:05
# Name: Duration, Length: 435, dtype: timedelta64[ns]

# %%
df['Duration'].sample()
# Out:
# 29   0 days 00:00:20
# Name: Duration, dtype: timedelta64[ns]

# %%
df
# Out:
#     Profile Name                Start Time        Duration  \
# 0             JB 2024-05-06 19:29:13+00:00 0 days 00:29:31
# 1             JB 2024-05-06 09:47:24+00:00 0 days 00:24:03
# 2             JB 2024-05-06 09:47:11+00:00 0 days 00:00:04
# 3             JB 2024-05-06 08:51:44+00:00 0 days 00:21:12
# 4             JB 2024-05-06 08:31:35+00:00 0 days 00:19:55
# ..           ...                       ...             ...
# 430           JB 2024-01-09 07:15:34+00:00 0 days 00:00:24
# 431           JB 2024-01-09 06:46:25+00:00 0 days 00:00:14
# 432           JB 2024-01-09 06:42:15+00:00 0 days 00:00:02
# 433           JB 2024-01-09 06:38:37+00:00 0 days 00:00:11
# 434           JB 2024-01-09 06:38:22+00:00 0 days 00:00:05
#
#                           Attributes  \
# 0                                NaN
# 1                                NaN
# 2    Autoplayed: user action: None;
# 3                                NaN
# 4                                NaN
# ...

# %%
df.loc[df['Profile Name'] == 'JB', 'Duration'].astype('timedelta64[s]')
# Out:
# 0     0 days 00:29:31
# 1     0 days 00:24:03
# 2     0 days 00:00:04
# 3     0 days 00:21:12
# 4     0 days 00:19:55
#             ...
# 430   0 days 00:00:24
# 431   0 days 00:00:14
# 432   0 days 00:00:02
# 433   0 days 00:00:11
# 434   0 days 00:00:05
# Name: Duration, Length: 435, dtype: timedelta64[s]

# %%
df.sample()
# Out:
#     Profile Name                Start Time        Duration Attributes   Title  \
# 241           JB 2024-02-14 03:48:07+00:00 0 days 00:02:58        NaN  Circle
#
#     Supplemental Video Type                     Device Type  Bookmark  \
# 241                     NaN  Google Sabrina ATV Set Top Box  00:02:59
#
#     Latest Bookmark             Country
# 241        00:02:59  US (United States)

# %%
df["Duration"].dtypes
# Out:
# dtype('<m8[ns]')

# %%
df.loc[df["Profile Name"] == "JB", "Duration"].astype('timedelta64[s]').sum().total_seconds()
# Out:
# 302087.0

# %%
viewTime = {}
viewTime.update({
    "JB" : df.loc[df["Profile Name"] == "JB", "Duration"].sum().total_seconds()
})
viewTime
# Out:
# {'JB': 302087.0}

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.bar(*zip(*viewTime.items()))
plt.show()

# %%
jb = df[df["Profile Name"]== "JB"].value_counts()

# %%
jb
# Out:
# Profile Name  Start Time                 Duration         Attributes                       Title                                                 Supplemental Video Type  Device Type                          Bookmark  Latest Bookmark  Country
# JB            2024-01-09 06:38:22+00:00  0 days 00:00:05  Autoplayed: user action: None;   Breaking Bad: Season 1_hook_primary_16x9              HOOK                     Netflix Chrome MAC (Cadmium) HTML 5  00:00:05  Not latest view  US (United States)    1
#               2024-01-09 06:38:37+00:00  0 days 00:00:11  Autoplayed: user action: None;   Breaking Bad: Season 1_hook_primary_16x9              HOOK                     Netflix Chrome MAC (Cadmium) HTML 5  00:00:11  Not latest view  US (United States)    1
# ...

# %%
df["Profile Name"].value_counts()
# Out:
# Profile Name
# JB    435
# Name: count, dtype: int64

# %%
df["Profile Name"].value_counts()
# Out:
# Profile Name
# JB    435
# Name: count, dtype: int64

# %%
df.loc[df["Profile Name"] == "JB", "Duration"].sum().total_seconds()
# Out:
# 302087.0

# %%
df.loc[df["Profile Name"] == "JB", "Duration"].sum()/435
# Out:
# Timedelta('0 days 00:11:34.452873563')

# %%
df["Supplemental Video Type"].value_counts()
# Out:
# Supplemental Video Type
# HOOK              82
# TRAILER           14
# TEASER_TRAILER     9
# RECAP              1
# PROMOTIONAL        1
# Name: count, dtype: int64

# %%
df.loc[df["Supplemental Video Type"].isnull()]
# Out:
#     Profile Name                Start Time        Duration Attributes  \
# 0             JB 2024-05-06 19:29:13+00:00 0 days 00:29:31        NaN
# 1             JB 2024-05-06 09:47:24+00:00 0 days 00:24:03        NaN
# 3             JB 2024-05-06 08:51:44+00:00 0 days 00:21:12        NaN
# 4             JB 2024-05-06 08:31:35+00:00 0 days 00:19:55        NaN
# 5             JB 2024-05-06 08:11:05+00:00 0 days 00:20:28        NaN
# ..           ...                       ...             ...        ...
# 426           JB 2024-01-09 08:23:49+00:00 0 days 00:19:47        NaN
# 427           JB 2024-01-09 08:16:50+00:00 0 days 00:06:39        NaN
# 428           JB 2024-01-09 08:16:30+00:00 0 days 00:00:04        NaN
# 429           JB 2024-01-09 07:21:12+00:00 0 days 00:42:20        NaN
# 432           JB 2024-01-09 06:42:15+00:00 0 days 00:00:02        NaN
#
#                                                Title Supplemental Video Type  \
# ...

# %%
df["Profile Name"].value_counts()
# Out:
# Profile Name
# JB    435
# Name: count, dtype: int64

# %%
n = df.loc[df['Supplemental Video Type'].isnull()]
p = n["Profile Name"].value_counts()
p
# Out:
# Profile Name
# JB    328
# Name: count, dtype: int64

# %%
filtered_data = df.loc[df["Supplemental Video Type"].isnull()]
filtered_data
# Out:
#     Profile Name                Start Time        Duration Attributes  \
# 0             JB 2024-05-06 19:29:13+00:00 0 days 00:29:31        NaN
# 1             JB 2024-05-06 09:47:24+00:00 0 days 00:24:03        NaN
# 3             JB 2024-05-06 08:51:44+00:00 0 days 00:21:12        NaN
# 4             JB 2024-05-06 08:31:35+00:00 0 days 00:19:55        NaN
# 5             JB 2024-05-06 08:11:05+00:00 0 days 00:20:28        NaN
# ..           ...                       ...             ...        ...
# 426           JB 2024-01-09 08:23:49+00:00 0 days 00:19:47        NaN
# 427           JB 2024-01-09 08:16:50+00:00 0 days 00:06:39        NaN
# 428           JB 2024-01-09 08:16:30+00:00 0 days 00:00:04        NaN
# 429           JB 2024-01-09 07:21:12+00:00 0 days 00:42:20        NaN
# 432           JB 2024-01-09 06:42:15+00:00 0 days 00:00:02        NaN
#
#                                                Title Supplemental Video Type  \
# ...

# %%
filtered_data["Profile Name"].value_counts()
# Out:
# Profile Name
# JB    328
# Name: count, dtype: int64

# %%
jb_duration = filtered_data.loc[filtered_data["Profile Name"] == "JB", "Duration"].sum()

# %%
jb_times = filtered_data["Profile Name"].value_counts()

# %%
average_time = jb_duration/jb_times
print(average_time)
# Out:
# Profile Name
# JB   0 days 00:15:14.271341463
# Name: count, dtype: timedelta64[ns]
